# %% [markdown]
# # AgentRadar-Stat API Collection, Cleaning, and EDA
#
# Stage 1 notebook placeholder. Run `python main.py` first, then load `data/processed/scored_repos.csv` here for exploration.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/scored_repos.csv')
df.head()
